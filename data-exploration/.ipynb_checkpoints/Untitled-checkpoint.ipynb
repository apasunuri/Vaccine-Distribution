# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../clean-data/combined-counties.csv")

# %%
df
# Out:
#        FIPS  OBJECTID  Countyname        ST_Name ST_Abbr  ST_ID  FatalityRa  \
# 0         0      3328                                         0    0.000000
# 1         0      3329                                         0    0.000000
# 2         0      3330                                         0    0.000000
# 3         0      3331                                         0    0.000000
# 4         0      3332                                         0    0.000000
# ...     ...       ...         ...            ...     ...    ...         ...
# 3328  90051      3318  Unassigned       Virginia              0    0.000000
# 3329  90053      3320  Unassigned     Washington              0    0.264901
# 3330  90054      3322  Unassigned  West Virginia              0    0.000000
# 3331  90055      3324  Unassigned      Wisconsin              0    0.000000
# 3332  90056      3326  Unassigned        Wyoming              0    0.000000
#
# ...

# %%
df = df[df["FIPS"] != 0]

# %%
df
# Out:
#        FIPS  OBJECTID  Countyname        ST_Name ST_Abbr  ST_ID  FatalityRa  \
# 6      1001         1     Autauga        Alabama      AL      1    1.536855
# 7      1003         2     Baldwin        Alabama      AL      1    1.457160
# 8      1005         3     Barbour        Alabama      AL      1    2.450980
# 9      1007         4        Bibb        Alabama      AL      1    2.265625
# 10     1009         5      Blount        Alabama      AL      1    2.070457
# ...     ...       ...         ...            ...     ...    ...         ...
# 3328  90051      3318  Unassigned       Virginia              0    0.000000
# 3329  90053      3320  Unassigned     Washington              0    0.264901
# 3330  90054      3322  Unassigned  West Virginia              0    0.000000
# 3331  90055      3324  Unassigned      Wisconsin              0    0.000000
# 3332  90056      3326  Unassigned        Wyoming              0    0.000000
#
# ...

# %%
df = df[df["Countyname"] != "Unassigned"]

# %%
df
# Out:
#        FIPS  OBJECTID Countyname        ST_Name ST_Abbr  ST_ID  FatalityRa  \
# 6      1001         1    Autauga        Alabama      AL      1    1.536855
# 7      1003         2    Baldwin        Alabama      AL      1    1.457160
# 8      1005         3    Barbour        Alabama      AL      1    2.450980
# 9      1007         4       Bibb        Alabama      AL      1    2.265625
# 10     1009         5     Blount        Alabama      AL      1    2.070457
# ...     ...       ...        ...            ...     ...    ...         ...
# 3277  80051      3317  Out of VA       Virginia              0    0.000000
# 3278  80053      3319  Out of WA     Washington              0    0.000000
# 3279  80054      3321  Out of WV  West Virginia              0    0.000000
# 3280  80055      3323  Out of WI      Wisconsin              0    0.000000
# 3281  80056      3325  Out of WY        Wyoming              0    0.000000
#
# ...

# %%
df = df[df["ST_ID"] != 0]

# %%
df
# Out:
#        FIPS  OBJECTID  Countyname  ST_Name ST_Abbr  ST_ID  FatalityRa  \
# 6      1001         1     Autauga  Alabama      AL      1    1.536855
# 7      1003         2     Baldwin  Alabama      AL      1    1.457160
# 8      1005         3     Barbour  Alabama      AL      1    2.450980
# 9      1007         4        Bibb  Alabama      AL      1    2.265625
# 10     1009         5      Blount  Alabama      AL      1    2.070457
# ...     ...       ...         ...      ...     ...    ...         ...
# 3146  56037      3139  Sweetwater  Wyoming      WY     56    0.907085
# 3147  56039      3140       Teton  Wyoming      WY     56    0.246373
# 3148  56041      3141       Uinta  Wyoming      WY     56    0.560748
# 3149  56043      3142    Washakie  Wyoming      WY     56    2.911534
# 3150  56045      3143      Weston  Wyoming      WY     56    0.782473
#
#       Confirmedb  DeathsbyPo  PCTPOVALL_  ...  Poverty Estimate, All Ages  \
# ...

# %%
df.columns.values
# Out:
# array(['FIPS', 'OBJECTID', 'Countyname', 'ST_Name', 'ST_Abbr', 'ST_ID',
#        'FatalityRa', 'Confirmedb', 'DeathsbyPo', 'PCTPOVALL_',
#        'Unemployme', 'Med_HH_Inc', 'State_Fata', 'DateChecke', 'EM_type',
#        'EM_date', 'EM_notes', 'url', 'Thumbnail', 'Confirmed', 'Deaths',
#        'Age_85', 'Age_80_84', 'Age_75_79', 'Age_70_74', 'Age_65_69',
#        'Beds_Licen', 'Beds_Staff', 'Beds_ICU', 'Ventilator', 'POP_ESTIMA',
#        'POVALL_201', 'Unemployed', 'Median_Hou', 'Recovered', 'Active',
#        'State_Conf', 'State_Deat', 'State_Reco', 'State_Test', 'AgedPop',
#        'NewCases', 'NewDeaths', 'TotalPop', 'NonHispWhP', 'BlackPop',
#        'AmIndop', 'AsianPop', 'PacIslPop', 'OtherPop', 'TwoMorPop',
#        'HispPop', 'Wh_Alone', 'Bk_Alone', 'AI_Alone', 'As_Alone',
#        'NH_Alone', 'SO_Alone', 'Two_More', 'Not_Hisp', 'Age_Less15',
#        'Age_15_24', 'Age_25_34', 'Age_Over75', 'Agetotal', 'NonHisp',
# ...

# %%
df.drop(columns=["OBJECTID", "ST_ID", "DateChecke", "EM_type", "EM_date", "EM_notes", "url", "Thumbnail"], inplace=True)
# Out:
# /Users/dallas/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.columns.values
# Out:
# array(['FIPS', 'Countyname', 'ST_Name', 'ST_Abbr', 'FatalityRa',
#        'Confirmedb', 'DeathsbyPo', 'PCTPOVALL_', 'Unemployme',
#        'Med_HH_Inc', 'State_Fata', 'Confirmed', 'Deaths', 'Age_85',
#        'Age_80_84', 'Age_75_79', 'Age_70_74', 'Age_65_69', 'Beds_Licen',
#        'Beds_Staff', 'Beds_ICU', 'Ventilator', 'POP_ESTIMA', 'POVALL_201',
#        'Unemployed', 'Median_Hou', 'Recovered', 'Active', 'State_Conf',
#        'State_Deat', 'State_Reco', 'State_Test', 'AgedPop', 'NewCases',
#        'NewDeaths', 'TotalPop', 'NonHispWhP', 'BlackPop', 'AmIndop',
#        'AsianPop', 'PacIslPop', 'OtherPop', 'TwoMorPop', 'HispPop',
#        'Wh_Alone', 'Bk_Alone', 'AI_Alone', 'As_Alone', 'NH_Alone',
#        'SO_Alone', 'Two_More', 'Not_Hisp', 'Age_Less15', 'Age_15_24',
#        'Age_25_34', 'Age_Over75', 'Agetotal', 'NonHisp', 'Age_35_64',
#        'Age_65_74', 'Day_1', 'Day_2', 'Day_3', 'Day_4', 'Day_5', 'Day_6',
# ...

# %%
cols = df.columns.values[4:]

# %%
cols
# Out:
# array(['FatalityRa', 'Confirmedb', 'DeathsbyPo', 'PCTPOVALL_',
#        'Unemployme', 'Med_HH_Inc', 'State_Fata', 'Confirmed', 'Deaths',
#        'Age_85', 'Age_80_84', 'Age_75_79', 'Age_70_74', 'Age_65_69',
#        'Beds_Licen', 'Beds_Staff', 'Beds_ICU', 'Ventilator', 'POP_ESTIMA',
#        'POVALL_201', 'Unemployed', 'Median_Hou', 'Recovered', 'Active',
#        'State_Conf', 'State_Deat', 'State_Reco', 'State_Test', 'AgedPop',
#        'NewCases', 'NewDeaths', 'TotalPop', 'NonHispWhP', 'BlackPop',
#        'AmIndop', 'AsianPop', 'PacIslPop', 'OtherPop', 'TwoMorPop',
#        'HispPop', 'Wh_Alone', 'Bk_Alone', 'AI_Alone', 'As_Alone',
#        'NH_Alone', 'SO_Alone', 'Two_More', 'Not_Hisp', 'Age_Less15',
#        'Age_15_24', 'Age_25_34', 'Age_Over75', 'Agetotal', 'NonHisp',
#        'Age_35_64', 'Age_65_74', 'Day_1', 'Day_2', 'Day_3', 'Day_4',
#        'Day_5', 'Day_6', 'Day_7', 'Day_8', 'Day_9', 'Day_10', 'Day_11',
# ...

# %%
for i in cols:
    print(i, df[i].dtype)
# Out:
# FatalityRa float64
# Confirmedb float64
# DeathsbyPo float64
# PCTPOVALL_ float64
# Unemployme float64
# Med_HH_Inc float64
# State_Fata float64
# Confirmed int64
# Deaths int64
# Age_85 int64
# Age_80_84 int64
# Age_75_79 int64
# Age_70_74 int64
# Age_65_69 int64
# Beds_Licen int64
# Beds_Staff int64
# Beds_ICU int64
# Ventilator int64
# POP_ESTIMA int64
# POVALL_201 int64
# Unemployed int64
# Median_Hou int64
# Recovered int64
# Active int64
# State_Conf int64
# State_Deat int64
# State_Reco int64
# State_Test int64
# AgedPop int64
# NewCases int64
# NewDeaths int64
# TotalPop int64
# NonHispWhP int64
# BlackPop int64
# AmIndop int64
# AsianPop int64
# PacIslPop int64
# OtherPop int64
# TwoMorPop int64
# HispPop int64
# Wh_Alone int64
# Bk_Alone int64
# AI_Alone int64
# As_Alone int64
# NH_Alone int64
# SO_Alone int64
# Two_More int64
# Not_Hisp int64
# Age_Less15 int64
# Age_15_24 int64
# Age_25_34 int64
# Age_Over75 int64
# Agetotal int64
# NonHisp int64
# Age_35_64 int64
# ...

# %%
df["Poverty Estimate, All Ages"] = df["Poverty Estimate, All Ages"].apply(lambda x: float(x) if (x != ".") else 0)
# Out:
# <ipython-input-28-ff3e24f3446d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Poverty Estimate, All Ages"] = df["Poverty Estimate, All Ages"].apply(lambda x: float(x) if (x != ".") else 0)

# %%
for i in cols:
    print(i, df[i].dtype)
# Out:
# FatalityRa float64
# Confirmedb float64
# DeathsbyPo float64
# PCTPOVALL_ float64
# Unemployme float64
# Med_HH_Inc float64
# State_Fata float64
# Confirmed int64
# Deaths int64
# Age_85 int64
# Age_80_84 int64
# Age_75_79 int64
# Age_70_74 int64
# Age_65_69 int64
# Beds_Licen int64
# Beds_Staff int64
# Beds_ICU int64
# Ventilator int64
# POP_ESTIMA int64
# POVALL_201 int64
# Unemployed int64
# Median_Hou int64
# Recovered int64
# Active int64
# State_Conf int64
# State_Deat int64
# State_Reco int64
# State_Test int64
# AgedPop int64
# NewCases int64
# NewDeaths int64
# TotalPop int64
# NonHispWhP int64
# BlackPop int64
# AmIndop int64
# AsianPop int64
# PacIslPop int64
# OtherPop int64
# TwoMorPop int64
# HispPop int64
# Wh_Alone int64
# Bk_Alone int64
# AI_Alone int64
# As_Alone int64
# NH_Alone int64
# SO_Alone int64
# Two_More int64
# Not_Hisp int64
# Age_Less15 int64
# Age_15_24 int64
# Age_25_34 int64
# Age_Over75 int64
# Agetotal int64
# NonHisp int64
# Age_35_64 int64
# ...

# %%
cols = list(cols)

# %%
cols.remove("Deaths")

# %%
np.corrcoef(df["Recovered"], df["Deaths"])
# Out:
# /Users/dallas/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2559: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/dallas/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2560: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# array([[nan, nan],
#        [nan,  1.]])

# %%
cols.append("Deaths")

# %%
correlation_df = df.drop(columns=["FIPS", "Countyname", "ST_Name", "ST_Abbr"])

# %%
for i in correlation_df.columns.values:
    print(correlation_df[i].dtype)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %%
usable = correlation_df.corr()

# %%
sns.heatmap(usable)
# Out:
# <AxesSubplot:>

# %%
strong = usable[abs(usable["Deaths"]) >= 0.9]

# %%
strong
# Out:
#                             FatalityRa  Confirmedb  DeathsbyPo  PCTPOVALL_  \
# Confirmed                    -0.044248    0.056607   -0.019153   -0.058370
# Deaths                        0.027462    0.047415    0.043999   -0.031650
# Age_85                       -0.026532   -0.018870   -0.038867   -0.092750
# Age_80_84                    -0.031211   -0.015164   -0.041458   -0.088753
# Age_75_79                    -0.034782   -0.018353   -0.046176   -0.090709
# Age_70_74                    -0.042185   -0.023208   -0.054792   -0.096001
# Age_65_69                    -0.045739   -0.024357   -0.058171   -0.095147
# POP_ESTIMA                   -0.051213   -0.008625   -0.054943   -0.081869
# POVALL_201                   -0.026718    0.012520   -0.021817    0.006210
# Unemployed                   -0.029563   -0.003223   -0.032040   -0.038310
# AgedPop                      -0.038764   -0.021246   -0.050813   -0.093746
# ...

# %%
square_strong = strong[strong.index]

# %%
sns.heatmap(square_strong)
# Out:
# <AxesSubplot:>

# %%
dfMax = correlation_df.max()
scaled = correlation_df.divide(dfMax, axis=1)

# %%
scaled
# Out:
#       FatalityRa  Confirmedb  DeathsbyPo  PCTPOVALL_  Unemployme  Med_HH_Inc  \
# 6       0.149843    0.324785    0.234577    0.273874    0.136029    0.476593
# 7       0.142073    0.259613    0.177783    0.187387    0.158088    0.473258
# 8       0.238971    0.237466    0.273525    0.553153    0.338235    0.263935
# 9       0.220898    0.305448    0.325223    0.326126    0.268382    0.385796
# 10      0.201870    0.301128    0.293004    0.245045    0.125000    0.400533
# ...          ...         ...         ...         ...         ...         ...
# 3146    0.088441    0.251536    0.107227    0.207207    0.224265    0.479204
# 3147    0.024021    0.421126    0.048760    0.109910    0.040441    0.542175
# 3148    0.054673    0.280447    0.073905    0.203604    0.231618    0.405956
# 3149    0.283875    0.298568    0.408527    0.189189    0.143382    0.346762
# 3150    0.076291    0.243287    0.089463    0.261261    0.150735    0.365157
#
# ...

# %%
s_corr = scaled.corr()

# %%
s_corr
# Out:
#                                  FatalityRa  Confirmedb  DeathsbyPo  \
# FatalityRa                         1.000000    0.063545    0.832197
# Confirmedb                         0.063545    1.000000    0.503667
# DeathsbyPo                         0.832197    0.503667    1.000000
# PCTPOVALL_                         0.235031    0.169368    0.289850
# Unemployme                         0.142884    0.022120    0.128378
# ...                                     ...         ...         ...
# PEDI_ICU_BEDS                     -0.053541   -0.001287   -0.052401
# BED_UTILIZATION                   -0.079644   -0.142231   -0.139727
# AVG_VENTILATOR_USAGE              -0.078799   -0.074568   -0.119085
# Potential_Increase_In_Bed_Capac   -0.033638    0.001000   -0.037392
# Population                        -0.053961   -0.016192   -0.062850
#
#                                  PCTPOVALL_  Unemployme  Med_HH_Inc  \
# FatalityRa                         0.235031    0.142884   -0.269953
# ...

# %%
scaled_strong = s_corr[abs(s_corr["Deaths"]) >= 0.9]

# %%
scaled_strong
# Out:
#                             FatalityRa  Confirmedb  DeathsbyPo  PCTPOVALL_  \
# Confirmed                    -0.044248    0.056607   -0.019153   -0.058370
# Deaths                        0.027462    0.047415    0.043999   -0.031650
# Age_85                       -0.026532   -0.018870   -0.038867   -0.092750
# Age_80_84                    -0.031211   -0.015164   -0.041458   -0.088753
# Age_75_79                    -0.034782   -0.018353   -0.046176   -0.090709
# Age_70_74                    -0.042185   -0.023208   -0.054792   -0.096001
# Age_65_69                    -0.045739   -0.024357   -0.058171   -0.095147
# POP_ESTIMA                   -0.051213   -0.008625   -0.054943   -0.081869
# POVALL_201                   -0.026718    0.012520   -0.021817    0.006210
# Unemployed                   -0.029563   -0.003223   -0.032040   -0.038310
# AgedPop                      -0.038764   -0.021246   -0.050813   -0.093746
# ...

# %%
strong_pop = usable[abs(usable["DeathsbyPo"]) >= 0.2]

# %%
strong_pop
# Out:
#             FatalityRa  Confirmedb  DeathsbyPo  PCTPOVALL_  Unemployme  \
# FatalityRa    1.000000    0.063545    0.832197    0.235031    0.142884
# Confirmedb    0.063545    1.000000    0.503667    0.169368    0.022120
# DeathsbyPo    0.832197    0.503667    1.000000    0.289850    0.128378
# PCTPOVALL_    0.235031    0.169368    0.289850    1.000000    0.640656
# Med_HH_Inc   -0.269953   -0.029432   -0.256859   -0.645596   -0.384513
# Median_Hou   -0.296459   -0.156439   -0.329464   -0.740124   -0.416889
#
#             Med_HH_Inc  State_Fata  Confirmed    Deaths    Age_85  ...  \
# FatalityRa   -0.269953    0.100482  -0.044248  0.027462 -0.026532  ...
# Confirmedb   -0.029432    0.082253   0.056607  0.047415 -0.018870  ...
# DeathsbyPo   -0.256859    0.124212  -0.019153  0.043999 -0.038867  ...
# PCTPOVALL_   -0.645596    0.019960  -0.058370 -0.031650 -0.092750  ...
# Med_HH_Inc    1.000000    0.122920   0.169629  0.124112  0.200156  ...
# ...

# %%
s_pop_square = strong_pop[strong_pop.index]

# %%
sns.heatmap(s_pop_square)
# Out:
# <AxesSubplot:>

# %%
strong_conf = usable[abs(usable["Confirmedb"]) >= 0.2]

# %%
strong_conf
# Out:
#             FatalityRa  Confirmedb  DeathsbyPo  PCTPOVALL_  Unemployme  \
# Confirmedb    0.063545    1.000000    0.503667    0.169368    0.022120
# DeathsbyPo    0.832197    0.503667    1.000000    0.289850    0.128378
#
#             Med_HH_Inc  State_Fata  Confirmed    Deaths    Age_85  ...  \
# Confirmedb   -0.029432    0.082253   0.056607  0.047415 -0.018870  ...
# DeathsbyPo   -0.256859    0.124212  -0.019153  0.043999 -0.038867  ...
#
#             Poverty Estimate, All Ages  NUM_LICENSED_BEDS  NUM_STAFFED_BEDS  \
# Confirmedb                    0.012323          -0.008312         -0.009664
# DeathsbyPo                   -0.022620          -0.049693         -0.049463
#
#             NUM_ICU_BEDS  ADULT_ICU_BEDS  PEDI_ICU_BEDS  BED_UTILIZATION  \
# Confirmedb     -0.008774       -0.008774      -0.001287        -0.142231
# DeathsbyPo     -0.052687       -0.052687      -0.052401        -0.139727
#
#             AVG_VENTILATOR_USAGE  Potential_Increase_In_Bed_Capac  Population
# ...

# %%
correlation_df.columns
# Out:
# Index(['FatalityRa', 'Confirmedb', 'DeathsbyPo', 'PCTPOVALL_', 'Unemployme',
#        'Med_HH_Inc', 'State_Fata', 'Confirmed', 'Deaths', 'Age_85',
#        'Age_80_84', 'Age_75_79', 'Age_70_74', 'Age_65_69', 'Beds_Licen',
#        'Beds_Staff', 'Beds_ICU', 'Ventilator', 'POP_ESTIMA', 'POVALL_201',
#        'Unemployed', 'Median_Hou', 'Recovered', 'Active', 'State_Conf',
#        'State_Deat', 'State_Reco', 'State_Test', 'AgedPop', 'NewCases',
#        'NewDeaths', 'TotalPop', 'NonHispWhP', 'BlackPop', 'AmIndop',
#        'AsianPop', 'PacIslPop', 'OtherPop', 'TwoMorPop', 'HispPop', 'Wh_Alone',
#        'Bk_Alone', 'AI_Alone', 'As_Alone', 'NH_Alone', 'SO_Alone', 'Two_More',
#        'Not_Hisp', 'Age_Less15', 'Age_15_24', 'Age_25_34', 'Age_Over75',
#        'Agetotal', 'NonHisp', 'Age_35_64', 'Age_65_74', 'Day_1', 'Day_2',
#        'Day_3', 'Day_4', 'Day_5', 'Day_6', 'Day_7', 'Day_8', 'Day_9', 'Day_10',
#        'Day_11', 'Day_12', 'Day_13', 'Day_14', 'NewCasebyP', 'Inpat_Occ',
# ...

# %%
strogn_newcases = usable[abs(usable["NewCasebyP"]) >= 0.2]

# %%
strogn_newcases
# Out:
#             FatalityRa  Confirmedb  DeathsbyPo  PCTPOVALL_  Unemployme  \
# NewCasebyP    0.068981    0.040957     0.06732   -0.038992   -0.001761
#
#             Med_HH_Inc  State_Fata  Confirmed   Deaths    Age_85  ...  \
# NewCasebyP    0.010953     0.04271   0.020575  0.02797  0.030692  ...
#
#             Poverty Estimate, All Ages  NUM_LICENSED_BEDS  NUM_STAFFED_BEDS  \
# NewCasebyP                    0.015839           0.022009          0.022799
#
#             NUM_ICU_BEDS  ADULT_ICU_BEDS  PEDI_ICU_BEDS  BED_UTILIZATION  \
# NewCasebyP      0.015346        0.015346       0.007343        -0.048029
#
#             AVG_VENTILATOR_USAGE  Potential_Increase_In_Bed_Capac  Population
# NewCasebyP               0.02878                         0.011904    0.025682
#
# [1 rows x 91 columns]

# %%
toKeep = [x for x in strong.index.values]

# %%
toKeep
# Out:
# ['Confirmed',
#  'Deaths',
#  'Age_85',
#  'Age_80_84',
#  'Age_75_79',
#  'Age_70_74',
#  'Age_65_69',
#  'POP_ESTIMA',
#  'POVALL_201',
#  'Unemployed',
#  'AgedPop',
#  'TotalPop',
#  'Age_Less15',
#  'Age_15_24',
#  'Age_25_34',
#  'Age_Over75',
#  'Agetotal',
#  'Age_35_64',
#  'Age_65_74',
#  'Poverty Estimate, All Ages',
#  'Population']

# %%
df
# Out:
#        FIPS  Countyname  ST_Name ST_Abbr  FatalityRa  Confirmedb  DeathsbyPo  \
# 6      1001     Autauga  Alabama      AL    1.536855    12101.84  185.987721
# 7      1003     Baldwin  Alabama      AL    1.457160     9673.45  140.957572
# 8      1005     Barbour  Alabama      AL    2.450980     8848.23  216.868420
# 9      1007        Bibb  Alabama      AL    2.265625    11381.32  257.858000
# 10     1009      Blount  Alabama      AL    2.070457    11220.33  232.312200
# ...     ...         ...      ...     ...         ...         ...         ...
# 3146  56037  Sweetwater  Wyoming      WY    0.907085     9372.49   85.016429
# 3147  56039       Teton  Wyoming      WY    0.246373    15691.58   38.659794
# 3148  56041       Uinta  Wyoming      WY    0.560748    10449.73   58.596611
# 3149  56043    Washakie  Wyoming      WY    2.911534    11124.95  323.906815
# 3150  56045      Weston  Wyoming      WY    0.782473     9065.12   70.932047
#
# ...

# %%
df.columns.values
# Out:
# array(['FIPS', 'Countyname', 'ST_Name', 'ST_Abbr', 'FatalityRa',
#        'Confirmedb', 'DeathsbyPo', 'PCTPOVALL_', 'Unemployme',
#        'Med_HH_Inc', 'State_Fata', 'Confirmed', 'Deaths', 'Age_85',
#        'Age_80_84', 'Age_75_79', 'Age_70_74', 'Age_65_69', 'Beds_Licen',
#        'Beds_Staff', 'Beds_ICU', 'Ventilator', 'POP_ESTIMA', 'POVALL_201',
#        'Unemployed', 'Median_Hou', 'Recovered', 'Active', 'State_Conf',
#        'State_Deat', 'State_Reco', 'State_Test', 'AgedPop', 'NewCases',
#        'NewDeaths', 'TotalPop', 'NonHispWhP', 'BlackPop', 'AmIndop',
#        'AsianPop', 'PacIslPop', 'OtherPop', 'TwoMorPop', 'HispPop',
#        'Wh_Alone', 'Bk_Alone', 'AI_Alone', 'As_Alone', 'NH_Alone',
#        'SO_Alone', 'Two_More', 'Not_Hisp', 'Age_Less15', 'Age_15_24',
#        'Age_25_34', 'Age_Over75', 'Agetotal', 'NonHisp', 'Age_35_64',
#        'Age_65_74', 'Day_1', 'Day_2', 'Day_3', 'Day_4', 'Day_5', 'Day_6',
# ...

# %%
df["Older_Population"] = df["Age_85"] + df["Age_80_84"] + df["Age_75_79"] + df["Age_70_74"] + df["Age_65_69"]
# Out:
# <ipython-input-133-be8f5cc72ba4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Older_Population"] = df["Age_85"] + df["Age_80_84"] + df["Age_75_79"] + df["Age_70_74"] + df["Age_65_69"]

# %%
df["Older_Population"]
# Out:
# 6        8283
# 7       42531
# 8        4710
# 9        3584
# 10      10326
#         ...
# 3146     4972
# 3147     3268
# 3148     2665
# 3149     1693
# 3150     1370
# Name: Older_Population, Length: 3143, dtype: int64

# %%
df["Older_by_pop"] = df["Older_Population"] / df["Population"]
# Out:
# <ipython-input-135-9fd2bd08fc98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Older_by_pop"] = df["Older_Population"] / df["Population"]

# %%
df.columns.values
# Out:
# array(['FIPS', 'Countyname', 'ST_Name', 'ST_Abbr', 'FatalityRa',
#        'Confirmedb', 'DeathsbyPo', 'PCTPOVALL_', 'Unemployme',
#        'Med_HH_Inc', 'State_Fata', 'Confirmed', 'Deaths', 'Age_85',
#        'Age_80_84', 'Age_75_79', 'Age_70_74', 'Age_65_69', 'Beds_Licen',
#        'Beds_Staff', 'Beds_ICU', 'Ventilator', 'POP_ESTIMA', 'POVALL_201',
#        'Unemployed', 'Median_Hou', 'Recovered', 'Active', 'State_Conf',
#        'State_Deat', 'State_Reco', 'State_Test', 'AgedPop', 'NewCases',
#        'NewDeaths', 'TotalPop', 'NonHispWhP', 'BlackPop', 'AmIndop',
#        'AsianPop', 'PacIslPop', 'OtherPop', 'TwoMorPop', 'HispPop',
#        'Wh_Alone', 'Bk_Alone', 'AI_Alone', 'As_Alone', 'NH_Alone',
#        'SO_Alone', 'Two_More', 'Not_Hisp', 'Age_Less15', 'Age_15_24',
#        'Age_25_34', 'Age_Over75', 'Agetotal', 'NonHisp', 'Age_35_64',
#        'Age_65_74', 'Day_1', 'Day_2', 'Day_3', 'Day_4', 'Day_5', 'Day_6',
# ...

# %%
df["Bed_Staff_by_pop"] = df["Beds_Staff"] / df["Population"]
df["ICU_Beds_by_pop"] = df["Beds_ICU"] / df["Population"]
df["Ventilator_by_pop"] = df["Ventilator"] / df["Population"]
df["Unemployment_Percentage"] = df["Unemployed"] / df["Population"]
df["Younger_Pop"] = df["Population"] - df["Older_Population"]
df["Younger_by_pop"] = df["Younger_Pop"] / df["Population"]
df["Licensed_Beds_by_pop"] = df["NUM_LICENSED_BEDS"] / df["Population"]
df["Staffed_Beds_by_pop"] = df["NUM_STAFFED_BEDS"] / df["Population"]
df["Poverty_by_pop"] = df["Poverty Estimate, All Ages"] / df["Population"]
# Out:
# <ipython-input-142-0c0c66e9a592>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Bed_Staff_by_pop"] = df["Beds_Staff"] / df["Population"]
# <ipython-input-142-0c0c66e9a592>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ICU_Beds_by_pop"] = df["Beds_ICU"] / df["Population"]
# <ipython-input-142-0c0c66e9a592>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
#        FIPS  Countyname  ST_Name ST_Abbr  FatalityRa  Confirmedb  DeathsbyPo  \
# 6      1001     Autauga  Alabama      AL    1.536855    12101.84  185.987721
# 7      1003     Baldwin  Alabama      AL    1.457160     9673.45  140.957572
# 8      1005     Barbour  Alabama      AL    2.450980     8848.23  216.868420
# 9      1007        Bibb  Alabama      AL    2.265625    11381.32  257.858000
# 10     1009      Blount  Alabama      AL    2.070457    11220.33  232.312200
# ...     ...         ...      ...     ...         ...         ...         ...
# 3146  56037  Sweetwater  Wyoming      WY    0.907085     9372.49   85.016429
# 3147  56039       Teton  Wyoming      WY    0.246373    15691.58   38.659794
# 3148  56041       Uinta  Wyoming      WY    0.560748    10449.73   58.596611
# 3149  56043    Washakie  Wyoming      WY    2.911534    11124.95  323.906815
# 3150  56045      Weston  Wyoming      WY    0.782473     9065.12   70.932047
#
# ...

# %%
df.columns.values
# Out:
# array(['FIPS', 'Countyname', 'ST_Name', 'ST_Abbr', 'FatalityRa',
#        'Confirmedb', 'DeathsbyPo', 'PCTPOVALL_', 'Unemployme',
#        'Med_HH_Inc', 'State_Fata', 'Confirmed', 'Deaths', 'Age_85',
#        'Age_80_84', 'Age_75_79', 'Age_70_74', 'Age_65_69', 'Beds_Licen',
#        'Beds_Staff', 'Beds_ICU', 'Ventilator', 'POP_ESTIMA', 'POVALL_201',
#        'Unemployed', 'Median_Hou', 'Recovered', 'Active', 'State_Conf',
#        'State_Deat', 'State_Reco', 'State_Test', 'AgedPop', 'NewCases',
#        'NewDeaths', 'TotalPop', 'NonHispWhP', 'BlackPop', 'AmIndop',
#        'AsianPop', 'PacIslPop', 'OtherPop', 'TwoMorPop', 'HispPop',
#        'Wh_Alone', 'Bk_Alone', 'AI_Alone', 'As_Alone', 'NH_Alone',
#        'SO_Alone', 'Two_More', 'Not_Hisp', 'Age_Less15', 'Age_15_24',
#        'Age_25_34', 'Age_Over75', 'Agetotal', 'NonHisp', 'Age_35_64',
#        'Age_65_74', 'Day_1', 'Day_2', 'Day_3', 'Day_4', 'Day_5', 'Day_6',
# ...

# %%
df["NonHispWh_by_pop"] = df["NonHispWhP"] / df["Population"]
df["Black_by_pop"] = df["BlackPop"] / df["Population"]
df["AmIn_by_pop"] = df["AmIndop"] / df["Population"]
df["Asian_by_pop"] = df["AsianPop"] / df["Population"]
df["PacIsl_by_pop"] = df["PacIslPop"] / df["Population"]
df["Otherpop_by_pop"] = df["OtherPop"] / df["Population"]
# Out:
# <ipython-input-145-da17e5f44694>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NonHispWh_by_pop"] = df["NonHispWhP"] / df["Population"]
# <ipython-input-145-da17e5f44694>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Black_by_pop"] = df["BlackPop"] / df["Population"]
# <ipython-input-145-da17e5f44694>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df["Two_More_by_pop"] = df["Two_More"] / df["Population"]
# Out:
# <ipython-input-147-1f6062e67c55>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Two_More_by_pop"] = df["Two_More"] / df["Population"]

# %%
df.columns.values
# Out:
# array(['FIPS', 'Countyname', 'ST_Name', 'ST_Abbr', 'FatalityRa',
#        'Confirmedb', 'DeathsbyPo', 'PCTPOVALL_', 'Unemployme',
#        'Med_HH_Inc', 'State_Fata', 'Confirmed', 'Deaths', 'Age_85',
#        'Age_80_84', 'Age_75_79', 'Age_70_74', 'Age_65_69', 'Beds_Licen',
#        'Beds_Staff', 'Beds_ICU', 'Ventilator', 'POP_ESTIMA', 'POVALL_201',
#        'Unemployed', 'Median_Hou', 'Recovered', 'Active', 'State_Conf',
#        'State_Deat', 'State_Reco', 'State_Test', 'AgedPop', 'NewCases',
#        'NewDeaths', 'TotalPop', 'NonHispWhP', 'BlackPop', 'AmIndop',
#        'AsianPop', 'PacIslPop', 'OtherPop', 'TwoMorPop', 'HispPop',
#        'Wh_Alone', 'Bk_Alone', 'AI_Alone', 'As_Alone', 'NH_Alone',
#        'SO_Alone', 'Two_More', 'Not_Hisp', 'Age_Less15', 'Age_15_24',
#        'Age_25_34', 'Age_Over75', 'Agetotal', 'NonHisp', 'Age_35_64',
#        'Age_65_74', 'Day_1', 'Day_2', 'Day_3', 'Day_4', 'Day_5', 'Day_6',
# ...

# %%
df["ICU_cap_by_pop"] = df["ICU_Cap"] / df["Population"]
df["Population_density"] = df["Population"] / df["Shape__Area"]
df["Testing_by_pop"] = df["State_Test"] / df["Population"]
quant_cols = ["Confirmedb", "DeathsbyPo", "Confirmed", "Deaths", "Median_Hou", "Recovered", "Active", "NewCases",
             "NewDeaths", "Older_by_pop", "Bed_Staff_by_pop", "ICU_Beds_by_pop", "Ventilator_by_pop",
             "Unemployment_Percentage", "Younger_by_pop", "Licensed_Beds_by_pop", "Staffed_Beds_by_pop",
             "Poverty_by_pop", "Licensed_Beds_by_pop", "NonHispWh_by_pop", "Black_by_pop", "AmIn_by_pop",
             "Asian_by_pop", "PacIsl_by_pop", "Otherpop_by_pop", "Two_More_by_pop", "Population_density"]
# Out:
# <ipython-input-199-eb41b31f67ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ICU_cap_by_pop"] = df["ICU_Cap"] / df["Population"]
# <ipython-input-199-eb41b31f67ba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Population_density"] = df["Population"] / df["Shape__Area"]
# <ipython-input-199-eb41b31f67ba>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
scaled_corr_df = df[quant_cols]

# %%
second_correlations = scaled_corr_df.corr()

# %%
second_correlations
# Out:
#                          Confirmedb  DeathsbyPo  Confirmed    Deaths  \
# Confirmedb                 1.000000    0.503667   0.056607  0.047415
# DeathsbyPo                 0.503667    1.000000  -0.019153  0.043999
# Confirmed                  0.056607   -0.019153   1.000000  0.955776
# Deaths                     0.047415    0.043999   0.955776  1.000000
# Median_Hou                -0.156439   -0.329464   0.213859  0.179186
# Recovered                       NaN         NaN        NaN       NaN
# Active                          NaN         NaN        NaN       NaN
# NewCases                   0.005995   -0.011969   0.664828  0.701314
# NewDeaths                  0.022113    0.018522   0.802570  0.836967
# Older_by_pop              -0.011853    0.011205   0.099871  0.105416
# Bed_Staff_by_pop           0.127221    0.141590   0.089916  0.085174
# ICU_Beds_by_pop            0.102490    0.149067   0.044435  0.038844
# Ventilator_by_pop          0.037900    0.039182   0.058231  0.059135
# ...

# %%
considered = second_correlations[abs(second_correlations["DeathsbyPo"]) >= 0.2]

# %%
considered
# Out:
#                   Confirmedb  DeathsbyPo  Confirmed    Deaths  Median_Hou  \
# Confirmedb          1.000000    0.503667   0.056607  0.047415   -0.156439
# DeathsbyPo          0.503667    1.000000  -0.019153  0.043999   -0.329464
# Median_Hou         -0.156439   -0.329464   0.213859  0.179186    1.000000
# Poverty_by_pop      0.154230    0.260376   0.055904  0.079912   -0.633205
# NonHispWh_by_pop   -0.196518   -0.333495  -0.123570 -0.140835    0.334701
# Black_by_pop        0.090235    0.204940   0.123459  0.132318   -0.209027
#
#                   Recovered  Active  NewCases  NewDeaths  Older_by_pop  ...  \
# Confirmedb              NaN     NaN  0.005995   0.022113     -0.011853  ...
# DeathsbyPo              NaN     NaN -0.011969   0.018522      0.011205  ...
# Median_Hou              NaN     NaN  0.242832   0.122864      0.079885  ...
# Poverty_by_pop          NaN     NaN  0.016811   0.078139     -0.095794  ...
# ...

# %%
square_considered = considered[considered.index.values]

# %%
sns.heatmap(square_considered)
# Out:
# <AxesSubplot:>

# %%
total_considered = second_correlations[abs(second_correlations["Deaths"]) >= 0.2]

# %%
total_considered
# Out:
#                     Confirmedb  DeathsbyPo  Confirmed    Deaths  Median_Hou  \
# Confirmed             0.056607   -0.019153   1.000000  0.955776    0.213859
# Deaths                0.047415    0.043999   0.955776  1.000000    0.179186
# NewCases              0.005995   -0.011969   0.664828  0.701314    0.242832
# NewDeaths             0.022113    0.018522   0.802570  0.836967    0.122864
# Asian_by_pop         -0.097499   -0.151300   0.357110  0.355791    0.455049
# Otherpop_by_pop      -0.041769   -0.025193   0.222407  0.252678    0.184263
# Population_density   -0.019735    0.014528   0.303046  0.417127    0.170797
#
#                     Recovered  Active  NewCases  NewDeaths  Older_by_pop  ...  \
# Confirmed                 NaN     NaN  0.664828   0.802570      0.099871  ...
# Deaths                    NaN     NaN  0.701314   0.836967      0.105416  ...
# NewCases                  NaN     NaN  1.000000   0.645067      0.116045  ...
# ...

# %%
square_total_considered = total_considered[total_considered.index.values]

# %%
sns.heatmap(square_total_considered)
# Out:
# <AxesSubplot:>

# %%
confirmed_considered = second_correlations[abs(second_correlations["Confirmed"]) >= 0.2]

# %%
confirmed_considered
# Out:
#                     Confirmedb  DeathsbyPo  Confirmed    Deaths  Median_Hou  \
# Confirmed             0.056607   -0.019153   1.000000  0.955776    0.213859
# Deaths                0.047415    0.043999   0.955776  1.000000    0.179186
# Median_Hou           -0.156439   -0.329464   0.213859  0.179186    1.000000
# NewCases              0.005995   -0.011969   0.664828  0.701314    0.242832
# NewDeaths             0.022113    0.018522   0.802570  0.836967    0.122864
# Asian_by_pop         -0.097499   -0.151300   0.357110  0.355791    0.455049
# Otherpop_by_pop      -0.041769   -0.025193   0.222407  0.252678    0.184263
# Population_density   -0.019735    0.014528   0.303046  0.417127    0.170797
#
#                     Recovered  Active  NewCases  NewDeaths  Older_by_pop  ...  \
# Confirmed                 NaN     NaN  0.664828   0.802570      0.099871  ...
# Deaths                    NaN     NaN  0.701314   0.836967      0.105416  ...
# ...

# %%
square_confirmed = confirmed_considered[confirmed_considered.index.values]

# %%
sns.heatmap(square_confirmed)
# Out:
# <AxesSubplot:>

# %%
cols_to_keep = set(confirmed_considered.index.values)

# %%
for i in total_considered.index.values:
    cols_to_keep.add(i)

# %%
cols_to_keep
# Out:
# {'Asian_by_pop',
#  'Confirmed',
#  'Deaths',
#  'Median_Hou',
#  'NewCases',
#  'NewDeaths',
#  'Otherpop_by_pop',
#  'Population_density'}

# %%
exportDF = df[cols_to_keep]

# %%
exportDF
# Out:
#       Median_Hou  NewCases  Asian_by_pop  Confirmed  NewDeaths  Deaths  \
# 6          58731        27      0.011953       6702          1     103
# 7          58320        15      0.011811      20588         -1     300
# 8          32525         5      0.004194       2244          0      55
# 9          47542         3      0.001277       2560          0      58
# 10         49358         3      0.003916       6472          1     134
# ...          ...       ...           ...        ...        ...     ...
# 3146       74843        12      0.008674       4079          0      37
# 3147       84678         8      0.016074       3653          0       9
# 3148       63403         0      0.001646       2140          0      12
# 3149       54158         1      0.000000        893          0      26
# 3150       57031         0      0.008100        639          0       5
#
#       Population_density  Otherpop_by_pop
# 6           2.169656e-05         0.001773
# ...

# %%
exportDF["FIPS"] = df["FIPS"]
# Out:
# <ipython-input-220-431df1d8988e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exportDF["FIPS"] = df["FIPS"]

# %%
exportDF
# Out:
#       Median_Hou  NewCases  Asian_by_pop  Confirmed  NewDeaths  Deaths  \
# 6          58731        27      0.011953       6702          1     103
# 7          58320        15      0.011811      20588         -1     300
# 8          32525         5      0.004194       2244          0      55
# 9          47542         3      0.001277       2560          0      58
# 10         49358         3      0.003916       6472          1     134
# ...          ...       ...           ...        ...        ...     ...
# 3146       74843        12      0.008674       4079          0      37
# 3147       84678         8      0.016074       3653          0       9
# 3148       63403         0      0.001646       2140          0      12
# 3149       54158         1      0.000000        893          0      26
# 3150       57031         0      0.008100        639          0       5
#
#       Population_density  Otherpop_by_pop   FIPS
# 6           2.169656e-05         0.001773   1001
# ...

# %%
df.columns.values
# Out:
# array(['FIPS', 'Countyname', 'ST_Name', 'ST_Abbr', 'FatalityRa',
#        'Confirmedb', 'DeathsbyPo', 'PCTPOVALL_', 'Unemployme',
#        'Med_HH_Inc', 'State_Fata', 'Confirmed', 'Deaths', 'Age_85',
#        'Age_80_84', 'Age_75_79', 'Age_70_74', 'Age_65_69', 'Beds_Licen',
#        'Beds_Staff', 'Beds_ICU', 'Ventilator', 'POP_ESTIMA', 'POVALL_201',
#        'Unemployed', 'Median_Hou', 'Recovered', 'Active', 'State_Conf',
#        'State_Deat', 'State_Reco', 'State_Test', 'AgedPop', 'NewCases',
#        'NewDeaths', 'TotalPop', 'NonHispWhP', 'BlackPop', 'AmIndop',
#        'AsianPop', 'PacIslPop', 'OtherPop', 'TwoMorPop', 'HispPop',
#        'Wh_Alone', 'Bk_Alone', 'AI_Alone', 'As_Alone', 'NH_Alone',
#        'SO_Alone', 'Two_More', 'Not_Hisp', 'Age_Less15', 'Age_15_24',
#        'Age_25_34', 'Age_Over75', 'Agetotal', 'NonHisp', 'Age_35_64',
#        'Age_65_74', 'Day_1', 'Day_2', 'Day_3', 'Day_4', 'Day_5', 'Day_6',
# ...

# %%
exportDF["Countyname"] = df["Countyname"]
exportDF["ST_Name"] = df["ST_Name"]
exportDF["Older_by_pop"] = df["Older_by_pop"]
# Out:
# <ipython-input-222-499ab4314d3d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exportDF["Countyname"] = df["Countyname"]
# <ipython-input-222-499ab4314d3d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exportDF["ST_Name"] = df["ST_Name"]
# <ipython-input-222-499ab4314d3d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
exportDF
# Out:
#       Median_Hou  NewCases  Asian_by_pop  Confirmed  NewDeaths  Deaths  \
# 6          58731        27      0.011953       6702          1     103
# 7          58320        15      0.011811      20588         -1     300
# 8          32525         5      0.004194       2244          0      55
# 9          47542         3      0.001277       2560          0      58
# 10         49358         3      0.003916       6472          1     134
# ...          ...       ...           ...        ...        ...     ...
# 3146       74843        12      0.008674       4079          0      37
# 3147       84678         8      0.016074       3653          0       9
# 3148       63403         0      0.001646       2140          0      12
# 3149       54158         1      0.000000        893          0      26
# 3150       57031         0      0.008100        639          0       5
#
#       Population_density  Otherpop_by_pop   FIPS  Countyname  ST_Name  \
# ...

# %%
to_export = exportDF.set_index("FIPS", drop=True)

# %%
to_export
# Out:
#        Median_Hou  NewCases  Asian_by_pop  Confirmed  NewDeaths  Deaths  \
# FIPS
# 1001        58731        27      0.011953       6702          1     103
# 1003        58320        15      0.011811      20588         -1     300
# 1005        32525         5      0.004194       2244          0      55
# 1007        47542         3      0.001277       2560          0      58
# 1009        49358         3      0.003916       6472          1     134
# ...           ...       ...           ...        ...        ...     ...
# 56037       74843        12      0.008674       4079          0      37
# 56039       84678         8      0.016074       3653          0       9
# 56041       63403         0      0.001646       2140          0      12
# 56043       54158         1      0.000000        893          0      26
# 56045       57031         0      0.008100        639          0       5
#
#        Population_density  Otherpop_by_pop  Countyname  ST_Name  Older_by_pop
# FIPS
# ...

# %%
to_export.to_csv("../clean-data/reduced-columns.csv")
