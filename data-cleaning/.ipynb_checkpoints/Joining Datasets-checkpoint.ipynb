# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
county_covid = pd.read_csv("../raw-data/County-Covid.csv")

# %%
county_covid.head()
# Out:
#    OBJECTID Countyname  ST_Name ST_Abbr  ST_ID  FIPS  FatalityRa  Confirmedb  \
# 0         1    Autauga  Alabama      AL      1  1001    1.536855    12101.84
# 1         2    Baldwin  Alabama      AL      1  1003    1.457160     9673.45
# 2         3    Barbour  Alabama      AL      1  1005    2.450980     8848.23
# 3         4       Bibb  Alabama      AL      1  1007    2.265625    11381.32
# 4         5     Blount  Alabama      AL      1  1009    2.070457    11220.33
#
#    DeathsbyPo  PCTPOVALL_  ...  Inpat_Occ    ICU_Occ   Inpat_Cap  Inpat_COV  \
# 0  185.987721        15.2  ...  44.019934  92.857143   86.000000   5.285714
# 1  140.957572        10.4  ...  51.903677  84.375000  439.000000  10.571429
# 2  216.868420        30.7  ...  53.602305   0.000000   49.571429   1.000000
# 3  257.858000        18.1  ...  28.571429        NaN   34.000000   0.000000
# 4  232.312200        13.6  ...  33.630952  59.523810   48.000000   0.000000
#
# ...

# %%
hosp_beds = pd.read_csv("../raw-data/Hospital-Beds.csv")

# %%
hosp_beds.head()
# Out:
#             X          Y  OBJECTID  \
# 0 -112.066157  33.495498         1
# 1 -110.965885  32.181263         2
# 2 -119.779742  36.773324         3
# 3  -72.957610  41.284400         4
# 4  -75.606533  39.740206         5
#
#                                        HOSPITAL_NAME HOSPITAL_TYPE  \
# 0  Phoenix VA Health Care System (AKA Carl T Hayd...   VA Hospital
# 1             Southern Arizona VA Health Care System   VA Hospital
# 2           VA Central California Health Care System   VA Hospital
# 3  VA Connecticut Healthcare System - West Haven ...   VA Hospital
# 4                       Wilmington VA Medical Center   VA Hospital
#
#                HQ_ADDRESS HQ_ADDRESS1     HQ_CITY HQ_STATE  HQ_ZIP_CODE  ...  \
# 0  650 E Indian School Rd         NaN     Phoenix       AZ        85012  ...
# 1          3601 S 6th Ave         NaN      Tucson       AZ        85723  ...
# 2      2615 E Clinton Ave         NaN      Fresno       CA        93703  ...
# ...

# %%
hosp_beds.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'HOSPITAL_NAME', 'HOSPITAL_TYPE', 'HQ_ADDRESS',
#        'HQ_ADDRESS1', 'HQ_CITY', 'HQ_STATE', 'HQ_ZIP_CODE', 'COUNTY_NAME',
#        'STATE_NAME', 'STATE_FIPS', 'CNTY_FIPS', 'FIPS', 'NUM_LICENSED_BEDS',
#        'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS', 'ADULT_ICU_BEDS', 'PEDI_ICU_BEDS',
#        'BED_UTILIZATION', 'AVG_VENTILATOR_USAGE',
#        'Potential_Increase_In_Bed_Capac'],
#       dtype='object')

# %%
populations = pd.read_excel("../raw-data/County-Populations.xls")

# %%
populations.head()
# Out:
#        Area_name  STCOU  POP665209F  POP665209D  POP665209N1  POP665209N2  \
# 0  UNITED STATES      0           0   260236655            0            0
# 1        ALABAMA   1000           0     4464199            0            0
# 2    Autauga, AL   1001           0       47936            0            0
# 3    Baldwin, AL   1003           0      165526            0            0
# 4    Barbour, AL   1005           0       28849            0            0
#
#    POP670209F  POP670209D  POP670209N1  POP670209N2  ...  POP700209N1  \
# 0           0     1622680            0            0  ...            0
# 1           0        5147            0            0  ...            0
# 2           0          44            0            0  ...            0
# 3           0         149            0            0  ...            0
# 4           0          19            0            0  ...            0
#
#    POP700209N2  POP710180F  POP710180D  POP710180N1  POP710180N2  POP710190F  \
# ...

# %%
poverty = pd.read_excel("../raw-data/County-Poverty.xls")
poverty.head()
# Out:
#            Table with column headers in rows 3 and 4        Unnamed: 1  \
# 0  2019 Poverty and Median Household Income Estim...               NaN
# 1                             Geographic Information               NaN
# 2                                    State FIPS Code  County FIPS Code
# 3                                                 00               000
# 4                                                 01               000
#
#     Unnamed: 2     Unnamed: 3                  Unnamed: 4          Unnamed: 5  \
# 0          NaN            NaN                         NaN                 NaN
# 1          NaN            NaN                    All Ages                 NaN
# 2  Postal Code           Name  Poverty Estimate, All Ages  90% CI Lower Bound
# 3           US  United States                    39490096            39248096
# 4           AL        Alabama                      747478              730491
#
# ...

# %%
cols = poverty.iloc[2].values
poverty.columns = cols

# %%
poverty = poverty.iloc[3:]
poverty.head()
# Out:
#   State FIPS Code County FIPS Code Postal Code            Name  \
# 3              00              000          US   United States
# 4              01              000          AL         Alabama
# 5              01              001          AL  Autauga County
# 6              01              003          AL  Baldwin County
# 7              01              005          AL  Barbour County
#
#   Poverty Estimate, All Ages 90% CI Lower Bound 90% CI Upper Bound  \
# 3                   39490096           39248096           39732096
# 4                     747478             730491             764465
# 5                       6723               5517               7929
# 6                      22360              18541              26179
# 7                       5909               4787               7031
#
#   Poverty Percent, All Ages 90% CI Lower Bound 90% CI Upper Bound  ...  \
# 3                      12.3               12.2               12.4  ...
# ...

# %%
poverty["FIPS"] = str(poverty["State FIPS Code"]).strip() + str(poverty["County FIPS Code"]).strip()

# %%
poverty["FIPS"] = poverty["State FIPS Code"] + poverty["County FIPS Code"]

# %%
poverty["FIPS"] = poverty["FIPS"].apply(lambda x: x[1:] if x[0] == "0" else x)

# %%
poverty.head()
# Out:
#   State FIPS Code County FIPS Code Postal Code            Name  \
# 3              00              000          US   United States
# 4              01              000          AL         Alabama
# 5              01              001          AL  Autauga County
# 6              01              003          AL  Baldwin County
# 7              01              005          AL  Barbour County
#
#   Poverty Estimate, All Ages 90% CI Lower Bound 90% CI Upper Bound  \
# 3                   39490096           39248096           39732096
# 4                     747478             730491             764465
# 5                       6723               5517               7929
# 6                      22360              18541              26179
# 7                       5909               4787               7031
#
#   Poverty Percent, All Ages 90% CI Lower Bound 90% CI Upper Bound  ...  \
# 3                      12.3               12.2               12.4  ...
# ...

# %%
poverty = poverty[["FIPS", "Poverty Estimate, All Ages"]]

# %%
poverty["FIPS"] = poverty["FIPS"].apply(lambda x: int(x))
# Out:
# <ipython-input-43-913996e58741>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty["FIPS"] = poverty["FIPS"].apply(lambda x: int(x))

# %%
test = county_covid.set_index("FIPS").join(poverty.set_index("FIPS"))

# %%
test[test["Countyname"] == "Alachua"]
# Out:
#        OBJECTID Countyname  ST_Name ST_Abbr  ST_ID  FatalityRa  Confirmedb  \
# FIPS
# 12001       321    Alachua  Florida      FL     12    1.091261     8941.28
#
#        DeathsbyPo  PCTPOVALL_  Unemployme  ...    ICU_Occ  Inpat_Cap  \
# FIPS                                       ...
# 12001   97.572737        21.4         5.1  ...  88.523002     1574.0
#
#        Inpat_COV   Inp_nonCOV ICU_Cap    ICU_COV  ICU_nonCOV   Shape__Area  \
# FIPS
# 12001  38.428571  1045.714286   295.0  10.571429  250.571429  3.334786e+09
#
#        Shape__Length  Poverty Estimate, All Ages
# FIPS
# 12001  301911.586741                       46916
#
# [1 rows x 93 columns]

# %%
county_covid["FIPS"].dtypes
# Out:
# dtype('int64')

# %%
hosp_beds[hosp_beds["COUNTY_NAME"] == "Alachua"]
# Out:
#               X          Y  OBJECTID  \
# 6    -82.345254  29.636989         7
# 693  -82.342674  29.639953       694
# 694  -82.411572  29.660304       695
# 4829 -82.343466  29.639833      4830
# 6396 -82.341241  29.639410      6397
# 6542 -82.364006  29.632219      6543
#
#                                           HOSPITAL_NAME  \
# 6     North Florida/South Georgia Veterans Health Sy...
# 693   UF Health Shands Hospital (FKA Shands at the U...
# 694               North Florida Regional Medical Center
# 4829            Select Specialty Hospital - Gainesville
# 6396  UF Health Neuromedicine Heart & Vascular Hospital
# 6542                           UF Health Rehab Hospital
#
#                        HOSPITAL_TYPE          HQ_ADDRESS HQ_ADDRESS1  \
# 6                        VA Hospital   1601 Sw Archer Rd         NaN
# 693   Short Term Acute Care Hospital   1600 Sw Archer Rd         NaN
# 694   Short Term Acute Care Hospital  6500 W Newberry Rd         NaN
# ...

# %%
hosp_beds["FIPS"] = hosp_beds["FIPS"].apply(lambda x: 0 if (x != x) else int(x))

# %%
hosp_beds
# Out:
#                X          Y  OBJECTID  \
# 0    -112.066157  33.495498         1
# 1    -110.965885  32.181263         2
# 2    -119.779742  36.773324         3
# 3     -72.957610  41.284400         4
# 4     -75.606533  39.740206         5
# ...          ...        ...       ...
# 6632 -110.984489  31.955757      6633
# 6633  -95.404182  29.803581      6634
# 6634  -85.765610  38.329353      6635
# 6635  -89.708786  45.890217      6636
# 6636  -83.092812  40.123219      6637
#
#                                           HOSPITAL_NAME  \
# 0     Phoenix VA Health Care System (AKA Carl T Hayd...
# 1                Southern Arizona VA Health Care System
# 2              VA Central California Health Care System
# 3     VA Connecticut Healthcare System - West Haven ...
# 4                          Wilmington VA Medical Center
# ...                                                 ...
# 6632                 Northwest Medical Center Sahuarita
# ...

# %%
hosp_beds.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'HOSPITAL_NAME', 'HOSPITAL_TYPE', 'HQ_ADDRESS',
#        'HQ_ADDRESS1', 'HQ_CITY', 'HQ_STATE', 'HQ_ZIP_CODE', 'COUNTY_NAME',
#        'STATE_NAME', 'STATE_FIPS', 'CNTY_FIPS', 'FIPS', 'NUM_LICENSED_BEDS',
#        'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS', 'ADULT_ICU_BEDS', 'PEDI_ICU_BEDS',
#        'BED_UTILIZATION', 'AVG_VENTILATOR_USAGE',
#        'Potential_Increase_In_Bed_Capac'],
#       dtype='object')

# %%
hosp = hosp_beds.groupby("FIPS").agg({"NUM_LICENSED_BEDS" : np.sum, "NUM_STAFFED_BEDS" : np.sum, "NUM_ICU_BEDS" : np.sum,
                              "ADULT_ICU_BEDS" : np.sum, "PEDI_ICU_BEDS" : np.sum, "BED_UTILIZATION" : np.average,
                              "AVG_VENTILATOR_USAGE" : np.average, "Potential_Increase_In_Bed_Capac" : np.sum})

# %%
hosp
# Out:
#        NUM_LICENSED_BEDS  NUM_STAFFED_BEDS  NUM_ICU_BEDS  ADULT_ICU_BEDS  \
# FIPS
# 0                  673.0             673.0            76              76
# 1001                85.0              55.0             6               6
# 1003               386.0             332.0            51              51
# 1005                74.0              30.0             5               5
# 1007                35.0              25.0             4               4
# ...                  ...               ...           ...             ...
# 72125              230.0             230.0            18              18
# 72127             2217.0            2217.0           260             260
# 72141                2.0               2.0             1               1
# 72145               90.0              90.0             6               6
# 72153               84.0              84.0            11              11
#
#        PEDI_ICU_BEDS  BED_UTILIZATION  AVG_VENTILATOR_USAGE  \
# FIPS
# ...

# %%
test2 = test.join(hosp)

# %%
test2
# Out:
#        OBJECTID  Countyname        ST_Name ST_Abbr  ST_ID  FatalityRa  \
# FIPS
# 0          3328                                         0    0.000000
# 0          3329                                         0    0.000000
# 0          3330                                         0    0.000000
# 0          3331                                         0    0.000000
# 0          3332                                         0    0.000000
# ...         ...         ...            ...     ...    ...         ...
# 90051      3318  Unassigned       Virginia              0    0.000000
# 90053      3320  Unassigned     Washington              0    0.264901
# 90054      3322  Unassigned  West Virginia              0    0.000000
# 90055      3324  Unassigned      Wisconsin              0    0.000000
# 90056      3326  Unassigned        Wyoming              0    0.000000
#
#        Confirmedb  DeathsbyPo  PCTPOVALL_  Unemployme  ...  Shape__Length  \
# ...

# %%
test2.columns
# Out:
# Index(['OBJECTID', 'Countyname', 'ST_Name', 'ST_Abbr', 'ST_ID', 'FatalityRa',
#        'Confirmedb', 'DeathsbyPo', 'PCTPOVALL_', 'Unemployme',
#        ...
#        'Shape__Length', 'Poverty Estimate, All Ages', 'NUM_LICENSED_BEDS',
#        'NUM_STAFFED_BEDS', 'NUM_ICU_BEDS', 'ADULT_ICU_BEDS', 'PEDI_ICU_BEDS',
#        'BED_UTILIZATION', 'AVG_VENTILATOR_USAGE',
#        'Potential_Increase_In_Bed_Capac'],
#       dtype='object', length=101)

# %%
populations["STCOU"].dtype
# Out:
# dtype('int64')

# %%
test2.index.dtype
# Out:
# dtype('int64')

# %%
populations.rename(columns={"POP665209D" : "Population"}, inplace=True)

# %%
populations.head()
# Out:
#        Area_name  STCOU  POP665209F  Population  POP665209N1  POP665209N2  \
# 0  UNITED STATES      0           0   260236655            0            0
# 1        ALABAMA   1000           0     4464199            0            0
# 2    Autauga, AL   1001           0       47936            0            0
# 3    Baldwin, AL   1003           0      165526            0            0
# 4    Barbour, AL   1005           0       28849            0            0
#
#    POP670209F  POP670209D  POP670209N1  POP670209N2  ...  POP700209N1  \
# 0           0     1622680            0            0  ...            0
# 1           0        5147            0            0  ...            0
# 2           0          44            0            0  ...            0
# 3           0         149            0            0  ...            0
# 4           0          19            0            0  ...            0
#
#    POP700209N2  POP710180F  POP710180D  POP710180N1  POP710180N2  POP710190F  \
# ...

# %%
populations["STCOU"]
# Out:
# 0           0
# 1        1000
# 2        1001
# 3        1003
# 4        1005
#         ...
# 3193    56037
# 3194    56039
# 3195    56041
# 3196    56043
# 3197    56045
# Name: STCOU, Length: 3198, dtype: int64

# %%
pops = populations[["STCOU", "Population"]]

# %%
pops.rename(columns={"STCOU" : "FIPS"}, inplace=True)
# Out:
# /Users/dallas/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
combined = test2.join(pops.set_index("FIPS"))

# %%
combined
# Out:
#        OBJECTID  Countyname        ST_Name ST_Abbr  ST_ID  FatalityRa  \
# FIPS
# 0          3328                                         0    0.000000
# 0          3329                                         0    0.000000
# 0          3330                                         0    0.000000
# 0          3331                                         0    0.000000
# 0          3332                                         0    0.000000
# ...         ...         ...            ...     ...    ...         ...
# 90051      3318  Unassigned       Virginia              0    0.000000
# 90053      3320  Unassigned     Washington              0    0.264901
# 90054      3322  Unassigned  West Virginia              0    0.000000
# 90055      3324  Unassigned      Wisconsin              0    0.000000
# 90056      3326  Unassigned        Wyoming              0    0.000000
#
#        Confirmedb  DeathsbyPo  PCTPOVALL_  Unemployme  ...  \
# ...

# %%
len(combined.columns)
# Out:
# 102

# %%
combined[combined["Countyname"] == "Alachua"]
# Out:
#        OBJECTID Countyname  ST_Name ST_Abbr  ST_ID  FatalityRa  Confirmedb  \
# FIPS
# 12001       321    Alachua  Florida      FL     12    1.091261     8941.28
#
#        DeathsbyPo  PCTPOVALL_  Unemployme  ...  Poverty Estimate, All Ages  \
# FIPS                                       ...
# 12001   97.572737        21.4         5.1  ...                       46916
#
#        NUM_LICENSED_BEDS NUM_STAFFED_BEDS NUM_ICU_BEDS ADULT_ICU_BEDS  \
# FIPS
# 12001             2034.0           1548.0        230.0          230.0
#
#       PEDI_ICU_BEDS BED_UTILIZATION AVG_VENTILATOR_USAGE  \
# FIPS
# 12001         130.0             NaN             8.666667
#
#        Potential_Increase_In_Bed_Capac  Population
# FIPS
# 12001                            486.0    211183.0
#
# [1 rows x 102 columns]

# %%
combined.to_csv("../clean-data/combined-counties.csv", index=True)
